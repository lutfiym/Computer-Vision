# %%
import numpy as np
import cv2
from PIL import Image
import matplotlib.pyplot as plt

# %%
img = cv2.imread('pelangi.jpg')
print(img)
# Out:
# [[[171 159 157]
#   [171 159 157]
#   [170 158 156]
#   ...
#   [135 125 115]
#   [138 128 118]
#   [140 130 120]]
#
#  [[171 159 157]
#   [171 159 157]
#   [170 158 156]
#   ...
#   [134 124 114]
#   [137 127 117]
#   [139 129 119]]
#
#  [[171 160 156]
#   [170 159 155]
#   [170 159 155]
#   ...
#   [132 122 112]
#   [135 125 115]
#   [137 127 117]]
#
#  ...
#
#  [[  0  40  53]
#   [  0   0  17]
#   [ 48 118 135]
#   ...
#   [ 38 101  99]
#   [  0   7  14]
#   [ 19   0  11]]
#
#  [[ 20  92 109]
#   [ 12 102 119]
#   [ 32  88 113]
#   ...
#   [ 92 171 162]
#   [ 88 144 145]
#   [  0   4  23]]
#
#  [[ 35 108 130]
#   [ 75 100 132]
#   [  8  51  84]
#   ...
#   [  5  51  45]
#   [180 252 252]
#   [ 49 124 138]]]

# %%
img.shape
# Out:
# (630, 1200, 3)

# %%
# Read image using OpenCV
img_cv = cv2.imread('pelangi.jpg')
img_cv
# Out:
# array([[[171, 159, 157],
#         [171, 159, 157],
#         [170, 158, 156],
#         ...,
#         [135, 125, 115],
#         [138, 128, 118],
#         [140, 130, 120]],
#
#        [[171, 159, 157],
#         [171, 159, 157],
#         [170, 158, 156],
#         ...,
#         [134, 124, 114],
#         [137, 127, 117],
#         [139, 129, 119]],
#
#        [[171, 160, 156],
#         [170, 159, 155],
#         [170, 159, 155],
#         ...,
#         [132, 122, 112],
#         [135, 125, 115],
#         [137, 127, 117]],
#
#        ...,
#
#        [[  0,  40,  53],
#         [  0,   0,  17],
#         [ 48, 118, 135],
#         ...,
#         [ 38, 101,  99],
#         [  0,   7,  14],
#         [ 19,   0,  11]],
#
#        [[ 20,  92, 109],
#         [ 12, 102, 119],
#         [ 32,  88, 113],
#         ...,
#         [ 92, 171, 162],
#         [ 88, 144, 145],
#         [  0,   4,  23]],
#
#        [[ 35, 108, 130],
#         [ 75, 100, 132],
#         [  8,  51,  84],
# ...

# %%
img_cv.shape
# Out:
# (630, 1200, 3)

# %%
# %matplotlib inline

# OpenCV starts from BGR
plt.imshow(img_cv)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (630, 1200)

# %%
plt.imshow(gray, cmap='gray')

# %%
gray[0:10,0:10]
# Out:
# array([[160, 160, 159, 158, 158, 158, 159, 159, 161, 158],
#        [160, 160, 159, 158, 158, 158, 158, 159, 160, 159],
#        [160, 159, 159, 158, 158, 158, 158, 158, 156, 157],
#        [160, 159, 158, 158, 157, 158, 158, 158, 153, 156],
#        [159, 159, 158, 157, 157, 157, 157, 158, 155, 157],
#        [159, 158, 158, 157, 157, 157, 157, 157, 159, 159],
#        [159, 158, 157, 157, 156, 157, 157, 157, 160, 159],
#        [158, 158, 157, 157, 156, 156, 157, 157, 159, 156],
#        [154, 158, 158, 155, 158, 164, 162, 154, 156, 158],
#        [159, 160, 159, 157, 158, 160, 158, 153, 158, 157]], dtype=uint8)

# %%
slice = gray[0:10,0:10]
plt.imshow(slice, cmap='gray')

# %%
# Shrink
img_re = cv2.resize(gray, (600,300), cv2.INTER_AREA)
img_re.shape
# Out:
# (300, 600)

# %%
plt.imshow(img_re, cmap='gray')

# %%
# Enlarge
img_re = cv2.resize(gray, (1800,900), cv2.INTER_AREA)
img_re.shape
# Out:
# (900, 1800)

# %%
plt.imshow(img_re, cmap='gray')
